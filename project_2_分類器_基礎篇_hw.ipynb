# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# Current directory
print(os.getcwd())

# change directory
os.chdir('/content/drive/MyDrive/python_training/NLP100Days/project_2_news_classf_1')
print(os.getcwd())
# Out:
# /content
# /content/drive/MyDrive/python_training/NLP100Days/project_2_news_classf_1

# %%
# !python --version
# Out:
# Python 3.7.10

# %%
# !pip install -q -U pip
# !pip install -q numpy
# !pip install -q pandas
# !pip install -q ckiptagger
# !pip install -q tqdm
# !pip install -q tensorflow==1.14.0
# !pip install -q ipywidgets

# %%
import pandas as pd
import numpy as np

from ckiptagger import WS, POS
from tqdm.notebook import tqdm
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df_train = pd.read_csv('news_clustering_train.tsv', sep='\t')
df_test = pd.read_csv('news_clustering_test.tsv', sep='\t')

# %%
df_train
# Out:
#       index class                            title
# 0         0    體育         亞洲杯奪冠賠率：日本、伊朗領銜 中國竟與泰國並列
# 1         1    體育        9輪4球本土射手僅次武磊 黃紫昌要搶最強U23頭銜
# 2         2    體育             如果今年勇士奪冠，下賽季詹姆斯何去何從？
# 3         3    體育            超級替補！科斯塔本賽季替補出場貢獻7次助攻
# 4         4    體育          騎士6天里發生了啥？從首輪搶七到次輪3-0猛龍
# ...     ...   ...                              ...
# 1795   1795    遊戲  LOL：麻辣香鍋韓服Rank不合成打野刀？電刀巨魔新套路連勝中
# 1796   1796    遊戲            穩住，我們能贏！因為我們擁有這種強大的力量
# 1797   1797    遊戲          騰訊是怎樣毀掉《鬥戰神》這款可能成神的作品的？
# 1798   1798    遊戲                   LOL你不知道的黑科技打法！
# 1799   1799    遊戲                 遊戲拳皇各代的劇情都在講些什麼？
#
# [1800 rows x 3 columns]

# %%
df_test
# Out:
#      index class                                title
# 0     1800    體育                   如果騎士火箭進入總決賽，誰的勝算大？
# 1     1801    體育             從個人競技狀態來看，三個階段的詹姆斯，哪個最強？
# 2     1802    體育       騎士總冠軍！地球人誰能阻擋詹姆斯？史上最佳就是他！打服所有人
# 3     1803    體育                   詹姆斯絕殺，騎士3比0，猛龍懷疑人生
# 4     1804    體育  騎士和步行者戰成搶七險勝，而猛龍即將被橫掃，步行者跟猛龍的區別在哪裡？
# ..     ...   ...                                  ...
# 595   2395    遊戲                           如何玩好《陰陽師》？
# 596   2396    遊戲                        網賺——玩遊戲網賺也不錯呦
# 597   2397    遊戲                          迷你世界怎麼跳四段跳？
# 598   2398    遊戲       DNF5000罐子挑戰遠古遺願，玩家最後只說了兩個字「坑爹」
# 599   2399    遊戲                     穿越火線那些被玩家吐槽的不足之處
#
# [600 rows x 3 columns]

# %%
train_titles = {row['index']: row['title'] for _, row in df_train.iterrows()}
train_classes = {row['index']: row['class'] for _, row in df_train.iterrows()}

test_titles = {row['index']: row['title'] for _, row in df_test.iterrows()}
test_classes = {row['index']: row['class'] for _, row in df_test.iterrows()}

# %%
train_titles[0] ##test_titles : {0: '亞洲杯奪冠賠率：日本、伊朗領銜 中國竟與泰國並列',1: , ...}
# Out:
# '亞洲杯奪冠賠率：日本、伊朗領銜 中國竟與泰國並列'

# %%
train_classes[0]  ##test_classes : {0: '體育', 1:  }
# Out:
# '體育'

# %%
all_news_class = ['體育', '財經', '科技', '旅遊', '農業', '遊戲']

# %% [markdown]
# # 斷詞(WS) + POS

# %%
ws = WS('../ckip_data/')
pos = POS('../ckip_data/')
# Out:
# WARNING: Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7fbe5a6e6c90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7fbe5a6e6c90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7fbe59c1c5d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7fbe59c1c5d0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7fbe59c1c550>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7fbe59c1c550>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7fbe59c16650>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7fbe59c16650>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fbe5a798ed0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fbe5a798ed0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7fbe41cf1290>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7fbe41cf1290>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7fbe41d05a50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7fbe41d05a50>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7fbe41c9cd90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7fbe41c9cd90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7fbe57f1eed0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method LSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7fbe57f1eed0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fbe57f30850>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fbe57f30850>>: AssertionError: Bad argument number for Name: 3, expecting 4

# %%
train_title_cuts = {}
for index, title in tqdm(train_titles.items()):
    # YOUR CODE HERE
    word_s = ws(
      [title]#,
      #sentence_segmentation = True, # To consider delimiters
      #segment_delimiter_set = {",", "。", ":", "?", "!", ";"}
      ) # This is the defualt set of delimiters
    word_p = pos(word_s)
    # END YOUR CODE
    train_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1800.0), HTML(value='')))

# %%
test_title_cuts = {}
for index, title in tqdm(test_titles.items()):
    # YOUR CODE HERE
    word_s = ws(
      [title]#,
      #sentence_segmentation = True, # To consider delimiters
      #segment_delimiter_set = {",", "。", ":", "?", "!", ";"}
      ) # This is the defualt set of delimiters
    word_p = pos(word_s)
    # END YOUR CODE
    test_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=600.0), HTML(value='')))

# %%
train_title_cuts[0] #0~1799 {0: [('亞洲杯', 'Nb'),  ('奪', 'VC'),  ('冠賠率', 'Na'),  ('：', 'COLONCATEGORY'),  ('日本', 'Nc'),] ,1: [..]
# Out:
# [('亞洲杯', 'Nb'),
#  ('奪', 'VC'),
#  ('冠賠率', 'Na'),
#  ('：', 'COLONCATEGORY'),
#  ('日本', 'Nc'),
#  ('、', 'PAUSECATEGORY'),
#  ('伊朗', 'Nc'),
#  ('領銜', 'VB'),
#  (' ', 'WHITESPACE'),
#  ('中國', 'Nc'),
#  ('竟', 'D'),
#  ('與', 'P'),
#  ('泰國', 'Nc'),
#  ('並列', 'VG')]

# %% [markdown]
# [('國腳', 'Na'),
#  ('張呈棟', 'Nb'),
#  ('：', 'COLONCATEGORY'),
#  ('從', 'D'),
#  ('沒', 'D'),
#  ('想', 'VE'),
#  ('過', 'Di'),
#  ('自己', 'Nh'),
#  ('會', 'D'),
#  ('出', 'VC'),
#  ('一', 'Neu'),
#  ('本', 'Nf'),
#  ('書', 'Na')]

# %%
test_title_cuts[1800] #1800~2399
# Out:
# [('如果', 'Cbb'),
#  ('騎士', 'Na'),
#  ('火箭', 'Na'),
#  ('進入', 'VCL'),
#  ('總決賽', 'Na'),
#  ('，', 'COMMACATEGORY'),
#  ('誰', 'Nh'),
#  ('的', 'DE'),
#  ('勝算', 'Na'),
#  ('大', 'VH'),
#  ('？', 'QUESTIONCATEGORY')]

# %% [markdown]
# # Bag of Words (BOW)

# %%
word2index = {}
index2word = {}
# 產生字與index對應的關係
# YOUR CODE HERE
n = 0
for index in train_title_cuts:
    for word, flag in train_title_cuts[index]:
        if word in word2index:
            continue
        word2index[word] = n 
        index2word[n] = word
        n += 1
# END YOUR CODE

# %%
word2index['溫暖']
# Out:
# 1520

# %%
index2word[1520]
# Out:
# '溫暖'

# %%
def get_bow_vector(pairs, word2index): ##pairs: (ws,pos)
    # YOUR CODE HERE
    vector = np.zeros(len(word2index))
    for word, flag in pairs:
        if word in word2index:
            vector[word2index[word]] += 1
    # END YOUR CODE
    return vector

# %%
get_bow_vector(train_title_cuts[120], word2index)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %% [markdown]
# # 排除較無意義的詞性

# %%
pos_analysis = {}
for _, pairs in train_title_cuts.items(): ### index,ws,pos
    for word, flag in pairs:
        if flag not in pos_analysis:
            pos_analysis[flag] = set()
        pos_analysis[flag].add(word)

for flag, words in pos_analysis.items():
    print(flag, ':', list(words)[:100])
    print('=======================')
# Out:
# Nb : ['泰拳王西', '馮天睿', '韋德', '碧生源', '昌圖', '切沃', '張大仙', '桑德羅', '勇士隊', '楊柳夏', '遼足', '游古', '王楚欽', '施泰納', 'J羅', '易', '雀巢', '石川佳純', '萊科寧', '榮威', '·龜茲', '林美景', '安卓', '劉偉', '朗多', '台積電', '建聯', '李嘉誠', '里坦克', '盼保', '德羅巴', '加威廉', '科爾', '布茲德里克', '德羅贊', '東決', '劉集', '白起', '韓信', '韓寒', '埃姆雷', '劉德華', '網傳', '王昭君', '朱嘯虎', '詹', '蓋倫', '騎士隊', '科斯塔', '盧克肖', '男乒', '德甲', '烏迪內斯', '谷歌', '李大霄', '拉卡拉', '藍星', '朱之文', '劉代全', '雅桑克萊', '泰山', '伯德', '美年達', '巴爾韋德', '章澤天', '中超', '張藝謀', 'G7', '王者榮耀', '德羅', '瓜迪奧拉', 'U23', '希金斯', '每日', '阿迪薩亞', '高傭', '波爾', '凱爾特', '泰倫', '海爾', '精准', '東皇', '凱西', '納米 華', '亞洲杯', '堪比比薩', '秦緒文', '余則成', '艷武漢', '溫格', '羅永浩', '卡帥', '弗格森', '安迪爾森', '馬克', '星巴克', '泰倫盧', '阿里雲', 'G3，76', '溫氏']
# =======================
# VC : ['爭', '募', '共進', '生產', '登頂', '指責', '放大', '花', '拼', '誤觸', '食用', '購買', '火遍', '好', '參', '包裝', '噴', '匯總', '解說', '利用', '推薦', '鋪開', '重建', '高產', '培育', '觀看', '提高', '舔', '戲耍', '開好', '打死', '學到', '拍拍', '過上', '扔上', '扔丟', '拍完', '提升到', '發售', '做好', '賒', '隱藏', '振興', '經營', '打開', '迎來', '綁定', '結出', '找', '分銷', '進行', '眾籌', '洩露', '接待', '買', '誤判', '拿下', '集訓', '打擊', '量', '加', '把握', '種點', '投放', '投入', '發展', '娶', '收錄', '刷到', '捕捉', '賞', '贊', '帶來', '安裝', '重做', '添脫', '保護', '瞪', '剪除', '添加', '下載', '評論', '藏', '解', '加強', '製造', '吊打', '抓緊', '萌爆', '咋回', '誘', '擇', '列', '團購', '提升', '冒充', '更換', '照看', '穿', '學好']
# =======================
# Na : ['爆料王者', '遊戲', '電線', '信號', '西紅柿', '塊鏈', '戰火箭', '土地', '大招', '蜜', '低保', '絕招', '藍煙', '效果', '老爸', '秘籍', '頭髮絲', '投票榜', '旅客', '鋼筋', '果汁', '概念股', '絕境', '制度', '耗電量', 'B組', '精品', '營收', '增長點', '果農', '地瓜', '連冠霸業', '碼', '東西', '選手', '月', '經典', '意義', '電流', '近距離', '農業', '裙子', '下場', '諾手', '穗期', '定制', '韓服', '花迪', '獸藥', '挑戰', '個性價比', '節奏榜', '辣椒', '博彩', '人', '車', '位', '盈利', '英雄榜', '雪', '宜興人', '武將', '雲海', '姓', '還本金', '飛車', '飛機票', '內臟水', '學子', '兒童', '熱潮', '花草', '藍色', '形態', '上聯', '官人', '紅薯苗', '糧食', '巴基斯坦人', '大仙', '助力', '寨', '暈腿', '果蔬', '課', '歌曲', '溫泉', '牛股', '榮譽', '格式', '全民', '夢符祭', '大賽', '精髓', '電網', '總經理', '景點', '人物', '大咖', '重量']
# =======================
# COLONCATEGORY : [':', '：']
# =======================
# Nc : ['上下游', '金融城', '保護區', '清水', '公司', '瑞典', '萊加內斯', '滎經縣', '絕地', '農村部', '宜昌', '青島', '富縣', '社區', '鵬城', '青島鄉', '渾江區', '果園地', '北極', '海岸', '煙台', '四國', '柯橋', '瑞士', '侗寨', '湖州', '倫貝爾', '雲端', '聖地', '杭州', '債市', '遼寧省', '加州', '洛陽', '哈尼梯田', '國', '戶外', '壽寧', '影視城', '北宅', '上位', '德', '民間', '水果店', '分行', '水鎮', '大洲島', '麻城', '房頂', '大麥灘', '劇情里', '波蘭', '洋溪鎮', '屏', '協會', '平遙', '九寨', '國外', '浙里', '萬寧', '秘境', '大連', '風景區', '北歐', 'WKG&M-1世界', '市場', '懸崖', '越南', '場', '聖托里尼亞', '成中路', '皖南', '加拿大', '易縣', '泰山', '東京', '開灤', '火山口', '情報站', '官總', '聊城', '東南亞', '巴中市', '阿拉德', '國道', '延邊', '地上', '亞馬遜', '珠海市', '海外', '便利店', '安居區', '分區', '三亞', '九寨溝', '拉薩', '山海', '紅河谷', '燴面店', '小學']
# =======================
# PAUSECATEGORY : ['、']
# =======================
# VB : ['鋪平', '拍照', '騙錢', '收回來', '扣分', '罰款', '加油', '相比', '退改', '通話', '執教', '分段', '代打', '抓來', '定位', '退款', '充飢', '解圍', '提前', '退貨', '解惑', '導航', '領銜', '鍍金', '入賬', '助威', '一網打盡', '再見', '加起來', '加持', '融資', '計算出來', '加工', '分紅', '充氣', '解密', '護航', '復仇', '解體', '上架', '站台', '效力', '罵屌絲', '分組', '開戰', '加冕', '應對']
# =======================
# WHITESPACE : [' ']
# =======================
# D : ['應該', '不要', '該', '不應該', '沒有', '互相', '已然', '首次', '難道', '首', '仍然', '並', '一路', '不會', '本來', '這麼', '哈哈', '微', '常常', '難以', '再次', '來', '率先', '自然', '本', '實在', '吃起來', '總', '多多少少', '絕', '接著', '未必', '硬生生', '不', '依舊', '居然', '互', '無法', '迫不及待', '卻', '永遠', '盡', '差點', '總會', '隨', '即', '冒死', '必然', '真', '連', '正在', '不能', '千萬', '差點兒', '別', '竟然', '剛', '始', '全力', '常', '已', '頻', '聯合', '親身', '偶爾', '皆', '一頭', '私', '能否', '快', '大概', '白', '好在', '一定', '怎麼', '可否', '再度', '剛剛', '甚至', '趁早', '略', '恐怕', '或許', '初', '如何', '會', '究竟', '必', '應當', '及時', '能', '好像', '去', '將', '有沒有', '只是', '獨', '少', '多多', '該不該']
# =======================
# P : ['臨', '向', '距離', '比如', '等', '往', '跟', '給', '像', '在', '幫', '離', '當', '為', '憑', '按', '和', '至', '從', '慘遭', '趁著', '為了', '除了', '被', '將', '因', '直至', '自從', '待', '用', '與', '除', '以', '就', '隨', '隨了', '趁', '於', '把', '比', '如', '繼', '遭', '關於', '到', '自', '靠', '針對', '對', '受', '根據']
# =======================
# VG : ['彷彿', '當作', '類似', '美成', '算是', '變成', '集成', '升任', '誤認成', '成為', '像', '改造成', '屈居', '猶如', '竟是', '等於', '當', '算', '為', '充當', '譽為', '稱為', '形成', '變', '理解為', '稱作', '投票成', '應聘', '並列', '非', '當上', '建成', '當成', '稱得上', '屬於', '排行', '做成', '名叫', '姓', '排', '酷似', '做', '封號', '賣成', '疑似', '作為', '似', '合成', '評選', '叫做', '排名', '戰成', '稱', '如', '堪稱', '化', '居', '叫', '成']
# =======================
# Neu : ['10萬', '2萬', '21', '24.8億', '幾千', '16', '72', '010', '十五萬', '7000', '1268', '600', '3:2', '二〇三', '500', '6800', '85', '135', '（二）', '三十', '2599', '2000', '50萬', '第三', '15萬', '6', '20萬', '四', '50', '30000億', '甲', '36萬', '3', '12', '11億', ' 360', '100萬', '億', '第四十四', '5', '3:1', '3000億', '5.7', 'b120', '711', '6.9', '十幾', '0:0', '700', '120', '7億', '兩', '1', '3:0', '第一', '4.5', '2018.', '0', '四五', '42', '11.59億', '，0', '2018-05-06 ', '150', '3000萬', '00', '2:1', '千萬', '1300', '3100', '91', '835', '1099', '萬', '46萬', '4.5億', '九', '一萬', '392億', '100多', '2888', '（四）', '幾', '1-2', '0-1', '2', '兩萬', '1.46億', '8萬', '30萬', '30', '80', '五一', '15.60', '120萬', '8.7億', '7300', '4000萬', '5.6千三', '2000萬']
# =======================
# Nf : ['日', '步', '層', '掛', '樣', '歲', '頁', '次', '關', '本', '項', '元', '塊', '番', '鍋', '晚', '名', '度', '胎', '張', '則', '噸', '群', '些', '對', '頭', '支', '回', '種', '處', '秒', '年', '戶', '畝', '條', '件', '株', '位', '台', '點', '遍', '級', '路', '周', '只', '批', '輛', '班', '套', '袋', '毛', '盤', '刻', '節', '週', '場', '分鐘', '串', '隊', '期', '片', '輪', '米', '部', '斤', '檔', '股', '棵', '所', '筆', '號', 'K', '槍', '把', '屆', '句', '類', '美元', '門', '隻', '港元', '分', '碗', '道', '天', '局', '款', '行', '個', '公里', '色', '英吋', '票', '口', '方', '家', '座', '頓', '招', '篇']
# =======================
# VJ : ['沒有', '惜', '晉級', '擁有', '僅次於', '嫌棄', '失去', '煥發', '順應', '失', '出於', '痛失', '優於', '錯失', '大勝', '達到', '充', '虧損', '忽視', '入選', '懷念', '出身', '值', '不敵', '獲', '震撼到', '展望', '新增', '佔', '歸', '毫無', '減持', '無', '贏下', '近', '翻倍', '贏得', '耗', '適應', '達', '脫', '處於', '遭遇', '領略', '冷落', '珍惜', '認識', '贊同', '高達', '曬', '為', '共有', '僅次', '受到', '負於', '強過', '歸屬於', '看懂', '吃上', '減', '發生', '不到', '獲得', '適用', '惹不起', '歡迎', '透', '共享', '維持', '缺', '緊缺', '抗', '沈迷', '錯過', '領跑', '超過', '靠', '發揮', '看好', '持有', '熱心', '自有', '過完', '經歷', '爆發', '遺傳', '關注', '含有', '懼怕', '衝', '缺少', '羨慕', '降至', '賽', '不理', '符合', '連接', '獨佔', '領先', '替代']
# =======================
# VD : ['交付', '拒賠', '貸款', '搶', '發放', '寄予', '提供', '傳', '給', '付', '借貸', '補貼', '予', '借', '白送', '坑', '分', '配', '賣', '禁售', '輸給', '輸', '轉讓', '供應', '贏', '欠', '發給', '發', '郵給', '清繳', '補繳', '還', '給予', '售', '貸', '速遞', '支付', '送', '收費']
# =======================
# Dfa : ['最', '不大', '好', '較', '同樣', '過', '這麼', '比較', '有點', '太', '還要', '超', '頗', '更為', '極', '遠遠', '過於', '十分', '多', '遠', '非常', '還', '更', '有些', '如此', '越來越', '很']
# =======================
# VH : ['真心', '原創', '長', '史無前例', '見底', '皆大歡喜', '神奇', '酷', '慘', '夠多', '辛酸', '好', '這麼', '爆表', '旺長', '窮', '合格', '摸不透', '畏難', '滿滿', '乾', '低迷', '交融', '極好', '過時', '重重', '易', '悲壯', '不可思議', '全自動', '主觀', '閃現', '完美', '茫然', '有名', '任性', '呆滯', '下跌', '良好', '靈活', '出道', '暖', '降價', '力輓狂瀾', '激增', '見分曉', '強硬', '到期', '當之無愧', '賞心悅目', '迅速', '快速', '可期', '渾濁', '後悔莫及', '虐汪', '強悍', '利', '超出口', '不足', '殫精竭慮', '系統', '嚴重', '夠', '穿', '滑滑', '舒適', '別具一格', '哭笑不得', '投機', '優秀', '原始', '吃', '跌', '色綠', '生存', '怎麼辦', '和睦', '暢快', '值錢', '變', '便宜', '浪費', '暴漲', '飽', '背水一戰', '重要', '新奇', '截止', '不當', '辛勞', '清淨', '積極', '強勢', '咸', '破產', '無效', '甜蜜', '無盡', '相關']
# =======================
# Cbb : ['還不如', '若', '不過', '既', '只要', '但是', '跟著', '但', '縱使', '並', '如果', '就算', '而', '因為', '雖然', '即使', '不僅', '假如', '另外', '要是', '因', '並且', '而是', '不管', '不然', '可是', '只有', '不如', '否則', '連', '反而', '既然']
# =======================
# Nd : ['6日', '大中', '五月份', '以後', '5月份', '15年', '雍正', '不久', '2018年度', '明晚', '1990年', '最後', '文化節', '2017年', '5月', '昨天', '過去', '今年', '15日', '5號', '8日', '未來', '永久', '後', '3月', '2005年', '今夏', '臨時', '九月', '春', '夜', '多久', '一會', '6旬', '19年', '當前', '初夏', '短期', '長期', '一日', '-5', '明日', '狗年', '30號', '當時', '如今', '同時', '採摘節', '熱天', '4月', '2035年', '昔日', '1日', '00年', '下旬', '8月', '今日', '晚上', '半夜', '六', '現在', '週二', '12日', '夏天', '周', '06日', '2019', '夏日', '以前', '90年', '週一', '秋', '夏季', '小時候', '後期', '後來', '05月', '幾月份', '五月', '夏', '2018', '月季', '今天', '31號', '明年', '首日', '季度', '一大早', '荒古', '13點', '晚清', '5.7日', '晚間', '隔年', '7號', '2018年', '2019年', '寒武紀', '春季', '23日']
# =======================
# VA : ['逃亡', '笑', '哭', '隨行', '墊腳', '吸粉', '坐', '來', '代言', '徒步', '遊園', '問津', '掛機', '大笑', '追債', '紮營', '娶妻', '封卡', '走起', '進去', '上線', '存在', '下班', '佈局', '聊天', '徜徉', '醫人', '備戰', '下場', '充電', '打卡', '打板', '砸盤', '歸來', '醒', '買單', '助攻', '下雪', '戰', '求生', '做種', '打工', '見面', '亮相', '降額', '起航', '跌', '上雙', '現身', '登高', '倒流', '下滑', '投訴', '說話', '喜極而泣', '開票', '血刃', '報名', '聯通', '誕生', '播種', '育秧', '出擊', '關機', '壓槍', '炒房', '看過來', '探秘', '續約', '滑雪', '工作', '開盤', '騎行', '抄底', '字字珠璣', '減稅', '實習', '付錢', '養花', '代工', '投標', '下山', '離隊', '鬥勇', '自殺', '成交', '流動', '相約', '抗詹', '唱空', '奮鬥', '創業', '遠行', '革命', '升', '偷鯤', '奪冠', '爭霸', '捲土重來', '控股']
# =======================
# COMMACATEGORY : [',', '，']
# =======================
# Nes : ['首', '每', '某', '下', '何', '該', '各', '貴', '同', '前', '後', '上', '另', '本', '頭', '近']
# =======================
# QUESTIONCATEGORY : ['？']
# =======================
# EXCLAMATIONCATEGORY : ['！', '!']
# =======================
# Di : ['著', '過', '個', '了', '起來']
# =======================
# Nep : ['此', '什麼', '那', '其中', '這', '哪', '啥', '其']
# =======================
# Caa : ['或者', '和', '或', '及', '跟', '暨', 'VS', '還是', '至', '比', '到', '又', '與', '或是']
# =======================
# VCL : ['升至', '路過', '回', '到達', '走下', '往', '在', '穿越', '回到', '跌出', '走訪', '穿過', '遊覽', '走進', '抵達', '過', '遠離', '進入', '存進', '橫掃', '出', '深入', '盤踞', '退出', '來到', '度過', '蒞臨', '前來', '重回', '入', '登陸', '赴', '走到', '去', '住', '暗渡', '回歸', '直達', '跌至', '走過', '穿透', '重返', '留在', '玩遍', '栽進', '進', '出發到', '到', '上', '前往', '用於']
# =======================
# Neqa : ['哪些', '0.8%', '1%', '一處處', '大多數', '部分', '9.89%', '80%', '所有', '12%', '1/4', '8%', '一點', '其它', '句句', '90%', '這麼多', '一切', '20%', '大量', '更多', '100%', '三分之一', '那些', '多少', '大多', '步步', '遍', '6%', '67%', '半', '有的', '四成', '10%', '多點', '這些', '多', '41.8%', '許多', '個個', '滴滴', '無數', '一半', '有些', '其他', '很多', '百分之八十', '一些', '30%', '不少', '15%', '任何', '全']
# =======================
# Nh : ['你', '自己', '自我', '它們', '誰', '各自', '她', '人家', '大家', '別人', '對方', '俺們', '父子倆', '各位', '本人', '我們', '他', '自身', '一方', '雙方', '她們', '個人', '屌絲', '我', '他們', '私人', '它', '您', '你們', '小眾']
# =======================
# FW : ['PS', 'cba', 'iPhone X', 'LOL：MSI', 'G+', 'iPhone X Plus', 'OV', 'DNF ', 'i7', 'e', 'VR', 'pro7', '5G', 'QM', 'wifi', 'Khan', ' CCR', 'Mc', '―', 'AMD', 'CCTV5', 'AI', 'PPP', '！DOTA2 MOD', 'Alan', 'iPad', 'lck', 'QGhappy', 'FF ', 'G3', 'Rookie', 'HTC', 'FPP', 'vs', 'T+0', 'bad boy', 'TT', 'Pro', 'Hello ', ' 樂', 'Brian Kelly', 'IG', 'DNF', 'Aloha', 'BCH', '<', 'AD', 'iBoy', '：BTC', 'OMG', 'h', 'Lol里', 'VS', 'Credo', 'Aurum ', '2', 'mc', 'CPI', 'B', 'KV', ' 展', 'msi', 'Instagram', 'QQ', '-0', 'eStarPro vs WF.D', 'LOL：', 'SIo', 'AWM', 'ipad', 'Soloking', 'MARVEL X', 'BAT', 'AP', ' 比', 'CCR', 'Fullestop', 'p', '+4', 'DNF：', 'VR ', ' MDL', 'DW', 'kpl', 'LPL', 'vip', 'MSI', 'King James', 'iphone6plus', 'S11', 'Q', 'IP', 'TPP', 'AIC', 'X', 'RNG', ' 2017', '-6', ' 28', 'l ']
# =======================
# SHI : ['像是', '是']
# =======================
# VE : ['申卡', '揭曉', '想到', '避免', '限制', '管', '探索', '想好', '證明', '報道', '做到', '聽到', '提醒', '聽', '以為', '預期', '看到', '檢測', '爆料', '提猜', '發佈', '估值', '公認', '慶祝', '深思', '回答', '想', '說', '形容', '查', '聽說', '呼籲', '反對', '提到', '預計', '判斷', '判定', '預測', '公示', '見證', '示範', '研究', '披露', '發誓', '查找', '炫耀', '看出', '安排', '告訴', '樂見', '確認', '訴說', '廣播', '見到', '傳聞', '防止', '調研', '宣佈', '提起', '探討', '認為', '假設', '算', '提', '感嘆', '公告', '發現', '商量', '問', '說明', '討說', '介紹', '談', '准', '聊', '公佈', '知詢', '考慮', '自嘲', '承諾', '預告', '要', '稱', '判罰', '證', '呼', '賭約', '精准', '允許', '盛贊', '鑒定', '抱怨', '設想', '暗示', '猜', '預定', '講', '幻想', '聯想', '禁止']
# =======================
# DE : ['的', '地', '之', '得']
# =======================
# VHC : ['傷', '團結', '繁榮', '凍', '豐富', '暫停', '愁死', '現代化', '變動', '滿足', '感動', '破', '平衡', '壞', '結束', '增 ', '增強', '下來', '公開', '增長', '產生', '恢復', '降低', '淡化', '優化', '增加', '普及', '告破', '國際化', '加快', '強化', '煩', '縮小', '辛苦', '溫暖', '陷', '開', '還原', '智能化', '冷卻', '停', '減少', '熱', '愁壞', '震驚', '可憐', '穩定', '麻煩', '肥', '擴張', '規模化', '斷', '機構化']
# =======================
# Ng : ['以後', '而言', '之前', '前', '之內', '以下', '外', '之外', '以外', '下', '中', '以上', '後', '來', '初', '間', '之上', '之後', '起', '左右', '為止', '般', '之下', '之間', '裡', '內', '底', '之中', '上', '以來', '時']
# =======================
# VK : ['盼', '知道', '流傳', '抱歉', '期待', '肯定', '顯示', '喜歡', '願意', '感謝', '忘', '信', '感受', '懷疑', '確定', '懂', '知', '害怕', '怕', '瞭解', '恐', '需要', '放心', '奇怪', '願', '欲', '不忘', '所謂', '遺憾', '介意', '恨', '小心', '堅持', '需', '回憶', '注意', '想見', '明白', '理解', '面臨', '意味', '懂得', '感覺', '感覺到', '依賴', '遇', '希望', '曲解', '忘記', '覺得', '覺', '意外', '意想不到', '擔心', '指望', '同意', '有利於', '不滿', '討厭']
# =======================
# Ncd : ['裡面', '那裡', '旁邊', '當中', '哪兒', '以下', '外', '東西部', '哪下', '兩旁', '中', '末端', '下', '間', '底部', '中間', '北', '東部', '西部', '中部', '那邊', '哪', '這裡', '畔', '方', '前沿', '哪裡', '一帶', '上方', '裡', '西', '上面', '內', '邊', '東方', '上', '東', '對面', '外面']
# =======================
# A : ['同等', '二手', '新興', '頭號', '常務', '主', '眾', '同一', '高度', '大幅度', '重磅', '多餘', '碧藍', '一般', '獨門', '新一代', '獨角', '中', '上上', '歐式', '最佳', '雙', '基礎', '非', '現役', '總', '原', '獨家', '綜合', '超', '小本', '麻辣', '寶有', '國產', '地下', '超級', '業餘', '前置', '額外', '長途', '單', '中西', '乒乓', '彩色', '真正', '後置', '必備', '野生', '唯一', '優質', '火紅', '基層', '共同', '現行']
# =======================
# V_2 : ['有']
# =======================
# VL : ['讓', '使得', '不惜', '令', '肯', '後悔', '趨於', '愛', '愛好', '習慣', '敢', '導致', '能', '故意', '持續', '便利', '開始', '甘願', '喜好', '用來', '致', '使']
# =======================
# T : ['咯', '矣', '的', '嗎', '去', '麼', '呢', '啦', '來', '哦', '哪', '吧', '了', '啊', '嘛']
# =======================
# VI : ['專用', '取勝', '驚艷', '傾心', '著稱']
# =======================
# DASHCATEGORY : ['—', '-']
# =======================
# I : ['哦', '瑪法里奧']
# =======================
# Dk : ['據說', '那麼', '結果', '那', '據聞', '想不到', '反過來', '外傳']
# =======================
# VF : ['試試', '請', '逼', '助', '停止', '繼續', '勸住', '止住', '催', '申請', '準備', '擬', '邀', '策劃', '拒', '試', '告誡', '鼓勵', '推選', '帶領', '打算', '勸說', '拒絕', '判', '要求', '率領', '圖', '叫']
# =======================
# Da : ['約', '幾乎', '幾近', '才', '正好', '只', '光', '不下', '僅', '足足', '將近', '唯獨', '最多', '近', '共']
# =======================
# PARENTHESISCATEGORY : ['）', '(', '》', '（', '」', '《', '「']
# =======================
# Nv : ['思考', '批發', '關聯', '生產', '銷售', '防治', '錄制', '經歷', '私募', '兼職', '旅遊', '遊樂', '推薦', '惡搞', '研究', '燃燒', '度假', '問', '絕殺', '增發', '開發', '疊加', '灌籃', '回歸', '買單', '射擊', '判罰', '創業', '體驗', '登山', '訴訟', '供電', '解救', '配置', '輔助', '代理', '工作', '崩潰', '管理', '抗戰', '航海', '組合', '分銷', '護髮', '營銷', '翻譯']
# =======================
# PERIODCATEGORY : ['。', '·']
# =======================
# VAC : ['移動', '動', '推進', '集合', '上演', '蒸發']
# =======================
# Dfb : ['些', '極了', '一點']
# =======================
# Cab : ['等等', '等']
# =======================
# SEMICOLONCATEGORY : ['；']
# =======================
# Neqb : ['幾', '以上', '半', '多']
# =======================
# ETCCATEGORY : ['…']
# =======================
# Cba : ['的話']
# =======================
# DOTCATEGORY : ['.']
# =======================

# %% [markdown]
# |         Type        |     Description    |
# |:-------------------:|:------------------:|
# | A                   | 非謂形容詞         |
# | Caa                 | 對等連接詞         |
# | Cab                 | 連接詞，如：等等   |
# | Cba                 | 連接詞，如：的話   |
# | Cbb                 | 關聯連接詞         |
# | D                   | 副詞               |
# | Da                  | 數量副詞           |
# | Dfa                 | 動詞前程度副詞     |
# | Dfb                 | 動詞後程度副詞     |
# | Di                  | 時態標記           |
# | Dk                  | 句副詞             |
# | DM                  | 定量式             |
# | I                   | 感嘆詞             |
# | Na                  | 普通名詞           |
# | Nb                  | 專有名詞           |
# | Nc                  | 地方詞             |
# | Ncd                 | 位置詞             |
# | Nd                  | 時間詞             |
# | Nep                 | 指代定詞           |
# | Neqa                | 數量定詞           |
# | Neqb                | 後置數量定詞       |
# | Nes                 | 特指定詞           |
# | Neu                 | 數詞定詞           |
# | Nf                  | 量詞               |
# | Ng                  | 後置詞             |
# | Nh                  | 代名詞             |
# | Nv                  | 名物化動詞         |
# | P                   | 介詞               |
# | T                   | 語助詞             |
# | VA                  | 動作不及物動詞     |
# | VAC                 | 動作使動動詞       |
# | VB                  | 動作類及物動詞     |
# | VC                  | 動作及物動詞       |
# | VCL                 | 動作接地方賓語動詞 |
# | VD                  | 雙賓動詞           |
# | VF                  | 動作謂賓動詞       |
# | VE                  | 動作句賓動詞       |
# | VG                  | 分類動詞           |
# | VH                  | 狀態不及物動詞     |
# | VHC                 | 狀態使動動詞       |
# | VI                  | 狀態類及物動詞     |
# | VJ                  | 狀態及物動詞       |
# | VK                  | 狀態句賓動詞       |
# | VL                  | 狀態謂賓動詞       |
# | V_2                 | 有                 |
# |                     |                    |
# | DE                  | 的之得地           |
# | SHI                 | 是                 |
# | FW                  | 外文               |
# |                     |                    |
# | COLONCATEGORY       | 冒號               |
# | COMMACATEGORY       | 逗號               |
# | DASHCATEGORY        | 破折號             |
# | DOTCATEGORY         | 點號               |
# | ETCCATEGORY         | 刪節號             |
# | EXCLAMATIONCATEGORY | 驚嘆號             |
# | PARENTHESISCATEGORY | 括號               |
# | PAUSECATEGORY       | 頓號               |
# | PERIODCATEGORY      | 句號               |
# | QUESTIONCATEGORY    | 問號               |
# | SEMICOLONCATEGORY   | 分號               |
# | SPCHANGECATEGORY    | 雙直線             |
# | WHITESPACE          | 空白               |

# %%
def get_bow_vector_with_selection(pairs, word2index):
    excluded_flags = [
        # 根據以上列舉出來的文字以及詞性表，請列出想要排除的詞性
        # YOUR CODE HERE
        'Nh', 'Nep', 'Nes', 'DE', 'T', 'P', 'V_2', 'SHI',
        'Dfa', 'Dfb', 'Da', 'Di', 'Dk',
        'Caa', 'Cab', 'Cba', 'Cbb',
        'COLONCATEGORY', 'COMMACATEGORY', 'DASHCATEGORY', 'DOTCATEGORY', 'ETCCATEGORY', 'EXCLAMATIONCATEGORY',
        'PARENTHESISCATEGORY', 'PAUSECATEGORY', 'PERIODCATEGORY', 'QUESTIONCATEGORY', 'SEMICOLONCATEGORY',
        'SPCHANGECATEGORY', 'WHITESPACE'
        # END YOUR CODE
    ]
    vector = np.zeros(len(word2index))
    for word, flag in pairs:
        if word in word2index and flag not in excluded_flags:
            vector[word2index[word]] += 1
    return vector

# %% [markdown]
# # Cosine Similarity

# %%
def cosine_similarity(bow1, bow2):
    # YOUR CODE HERE
    len_bow1 = np.sqrt(np.sum(np.square(bow1)))
    len_bow2 = np.sqrt(np.sum(np.square(bow2)))
    similarity = np.sum(bow1 * bow2) / (len_bow1 * len_bow2)
    # END YOUR CODE
    return similarity

# %%
bow1 = get_bow_vector(train_title_cuts[100], word2index)
bow2 = get_bow_vector(train_title_cuts[130], word2index)
cosine_similarity(bow1, bow2)
# Out:
# 0.08703882797784893

# %%
train_title_cuts[100]
# Out:
# [('山東', 'Nc'),
#  ('魯能', 'Nb'),
#  ('有沒有', 'D'),
#  ('可能', 'D'),
#  ('拿到', 'VC'),
#  ('今年', 'Nd'),
#  ('的', 'DE'),
#  ('中', 'A'),
#  ('超', 'A'),
#  ('冠軍', 'Na'),
#  ('？', 'QUESTIONCATEGORY')]

# %%
train_title_cuts[130]
# Out:
# [('NBA', 'Nb'),
#  ('和', 'Caa'),
#  ('CBA', 'FW'),
#  ('差距', 'Na'),
#  ('在', 'P'),
#  ('哪裡', 'Ncd'),
#  ('？', 'QUESTIONCATEGORY'),
#  ('6', 'Neu'),
#  ('張', 'Nf'),
#  ('圖', 'VF'),
#  ('一目瞭然', 'VH'),
#  ('！', 'EXCLAMATIONCATEGORY')]

# %% [markdown]
# # Group mean vector

# %%
group_vectors = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(train_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    news_class = train_classes[index]
    group_vectors[news_class].append(vector)

group_mean_vector = {}
for news_class, vectors in group_vectors.items():
    group_mean_vector[news_class] = np.mean(vectors, axis=0)
group_mean_vector
# Out:
# {'旅遊': array([0., 0., 0., ..., 0., 0., 0.]),
#  '科技': array([0., 0., 0., ..., 0., 0., 0.]),
#  '財經': array([0., 0., 0., ..., 0., 0., 0.]),
#  '農業': array([0., 0., 0., ..., 0., 0., 0.]),
#  '遊戲': array([0.        , 0.        , 0.        , ..., 0.00333333, 0.00333333,
#         0.00333333]),
#  '體育': array([0.04      , 0.01333333, 0.00333333, ..., 0.        , 0.        ,
#         0.        ])}

# %% [markdown]
# # Group mean vector: 測試

# %%
classification = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(test_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    if np.sum(np.square(vector)) == 0:
        continue

    max_val = -2.0
    max_class = None
    for news_class, ref_vector in group_mean_vector.items():
        val = cosine_similarity(ref_vector, vector)
        if val > max_val:
            max_class = news_class
            max_val = val

    classification[max_class].append(index)

# %%
from collections import Counter

for group, ids in classification.items():
    counter = Counter([test_classes[id] for id in ids])
    print('predict', group, ': ', counter)
# Out:
# predict 體育 :  Counter({'體育': 73, '遊戲': 8, '財經': 6, '旅遊': 6, '農業': 6, '科技': 3})
# predict 財經 :  Counter({'財經': 67, '科技': 18, '體育': 6, '旅遊': 6, '遊戲': 6, '農業': 5})
# predict 科技 :  Counter({'科技': 62, '財經': 13, '體育': 10, '農業': 6, '遊戲': 6, '旅遊': 2})
# predict 旅遊 :  Counter({'旅遊': 70, '農業': 11, '財經': 6, '科技': 3, '遊戲': 2})
# predict 農業 :  Counter({'農業': 70, '旅遊': 9, '科技': 6, '體育': 5, '財經': 4, '遊戲': 3})
# predict 遊戲 :  Counter({'遊戲': 75, '科技': 7, '旅遊': 5, '體育': 4, '財經': 4, '農業': 1})

# %% [markdown]
# predict 體育 :  Counter({'體育': 73, '遊戲': 8, '財經': 6, '旅遊': 6, '農業': 6, '科技': 3})
#
# predict 財經 :  Counter({'財經': 67, '科技': 18, '體育': 6, '旅遊': 6, '遊戲': 6, '農業': 5})
#
# predict 科技 :  Counter({'科技': 62, '財經': 13, '體育': 10, '農業': 6, '遊戲': 6, '旅遊': 2})
#
# predict 旅遊 :  Counter({'旅遊': 70, '農業': 11, '財經': 6, '科技': 3, '遊戲': 2})
#
# predict 農業 :  Counter({'農業': 70, '旅遊': 9, '科技': 6, '體育': 5, '財經': 4, '遊戲': 3})
#
# predict 遊戲 :  Counter({'遊戲': 75, '科技': 7, '旅遊': 5, '體育': 4, '財經': 4, '農業': 1})
