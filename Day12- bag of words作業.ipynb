# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ---

# %%
import os

# Current directory
print(os.getcwd())

# change directory
os.chdir('/content/drive/MyDrive/python_training/NLP100Days/day_12_BOW/')
print(os.getcwd())
! pip install -q sklearn_crfsuite
! pip install -q nltk
! pip install -q scikit-learn
# Out:
# /content/drive/My Drive/python_training/NLP100Days/day_12_BOW
# /content/drive/MyDrive/python_training/NLP100Days/day_12_BOW

# %%
import pandas as pd
import nltk
#nltk.download()
#nltk.download('treebank')
#nltk.download('universal_tagset')
nltk.download('punkt')
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
dataset[0:2]
# Out:
#                      Review  Liked
# 0  Wow... Loved this place.      1
# 1        Crust is not good.      0

# %%
corpus[0:2]
# Out:
# array(['Wow... Loved this place.', 'Crust is not good.'], dtype=object)

# %%
dataset.shape
# Out:
# (1000, 2)

# %% [markdown]
# ### 從文本中取出所有單字

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)

# %%
whole_words[0:9]
# Out:
# ['Wow', '...', 'Loved', 'this', 'place', '.', 'Crust', 'is', 'not']

# %%
len(whole_words)
# Out:
# 12676

# %% [markdown]
# ### 移除重複單字

# %%
whole_words = set(whole_words)
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2356個單字

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    word_index[word] = n 
    index_word[n] = word
    n+=1

# %%
word_index
# Out:
# {'Up': 0,
#  'salt': 1,
#  'flavourful': 2,
#  'Please': 3,
#  'Bar': 4,
#  'other': 5,
#  'bamboo': 6,
#  'room': 7,
#  'deep': 8,
#  'batch': 9,
#  'number': 10,
#  'appalling': 11,
#  'soup': 12,
#  'postinos': 13,
#  'As': 14,
#  'anyone': 15,
#  'dates': 16,
#  'needs': 17,
#  'fellow': 18,
#  'mean': 19,
#  'comfortable': 20,
#  'handed': 21,
#  'cheek': 22,
#  'fails': 23,
#  'non-fancy': 24,
#  'must': 25,
#  'afternoon': 26,
#  'several': 27,
#  'together': 28,
#  'our': 29,
#  'Service': 30,
#  'sick': 31,
#  'perfection': 32,
#  'call': 33,
#  'Thus': 34,
#  'Once': 35,
#  'juries': 36,
#  'Del': 37,
#  'head': 38,
#  'try': 39,
#  'transcendant': 40,
#  'further': 41,
#  '40min': 42,
#  'sewer': 43,
#  'descriptions': 44,
#  '35': 45,
#  'claimed': 46,
#  'Veggitarian': 47,
#  'quite': 48,
#  'Burrittos': 49,
#  'listed': 50,
#  'reviewing..': 51,
#  'calamari': 52,
#  'quantity': 53,
#  'greedy': 54,
#  'very': 55,
#  'contained': 56,
#  'Damn': 57,
#  'Yeah': 58,
#  'gratuity': 59,
#  'rated': 60,
#  'horrible': 61,
#  'figured': 62,
#  '3': 63,
#  'North': 64,
#  'playing': 65,
#  'brick': 66,
#  'IT': 67,
#  'bring': 68,
#  'Con': 69,
#  'mention': 70,
#  'black': 71,
#  'Bacon': 72,
#  'disbelief': 73,
#  'Café': 74,
#  'seated': 75,
#  'WEAK': 76,
#  'disrespected': 77,
#  'ice': 78,
#  'done': 79,
#  'temp.I': 80,
#  'ethic': 81,
#  'indoor': 82,
#  '%': 83,
#  'Tried': 84,
#  'nude': 85,
#  'eyed': 86,
#  'mood': 87,
#  'STEP': 88,
#  'experienced': 89,
#  'having': 90,
#  'RI': 91,
#  'also': 92,
#  'strawberry': 93,
#  'OVERPRICED': 94,
#  'tap': 95,
#  'multi-grain': 96,
#  'door': 97,
#  'Be': 98,
#  'street': 99,
#  'disgusting': 100,
#  'Italian': 101,
#  'potato': 102,
#  'One': 103,
#  'eggplant': 104,
#  'wave': 105,
#  'summarize': 106,
#  'definately': 107,
#  'callings': 108,
#  'NONE': 109,
#  'For': 110,
#  'anymore': 111,
#  'Steiners': 112,
#  'suggestions': 113,
#  'Salads': 114,
#  'meats': 115,
#  'help': 116,
#  'one': 117,
#  'seasonal': 118,
#  'Some': 119,
#  'array': 120,
#  'disgust': 121,
#  'ladies': 122,
#  'etc': 123,
#  'brother': 124,
#  'strings': 125,
#  '.very': 126,
#  'HAPPENED': 127,
#  'tasteless': 128,
#  'bagels': 129,
#  'wash': 130,
#  'great': 131,
#  'should': 132,
#  'awesome': 133,
#  'of': 134,
#  'milkshake': 135,
#  'These': 136,
#  "ya'all": 137,
#  'closed': 138,
#  'low-key': 139,
#  'recommended': 140,
#  'Indian': 141,
#  'chipolte': 142,
#  'exquisite': 143,
#  'Everyone': 144,
#  'outshining': 145,
#  'Gyros': 146,
#  'Interesting': 147,
#  'Shop': 148,
#  'suck': 149,
#  'least': 150,
#  'AGAIN': 151,
#  'bakery': 152,
#  'above': 153,
#  'mains': 154,
#  'got': 155,
#  'Thoroughly': 156,
#  "'d": 157,
#  'cafe': 158,
#  'Sour': 159,
#  'drive': 160,
#  'double': 161,
#  'Christmas': 162,
#  'owner': 163,
#  'workers': 164,
#  'friend': 165,
#  'impressed': 166,
#  'perfect': 167,
#  'deliver': 168,
#  'mozzarella': 169,
#  'operation': 170,
#  'Japanese': 171,
#  'ridiculous': 172,
#  'unhealthy': 173,
#  'meal': 174,
#  'service': 175,
#  'Nan': 176,
#  'melted': 177,
#  'bartender': 178,
#  'Voodoo': 179,
#  'GO': 180,
#  'either': 181,
#  'correction': 182,
#  'missing': 183,
#  'then': 184,
#  'original': 185,
#  'stir': 186,
#  'tater': 187,
#  'dog': 188,
#  'homemade': 189,
#  'lawyers': 190,
#  'tuna': 191,
#  'Lastly': 192,
#  'Oh': 193,
#  'bother': 194,
#  'Disappointing': 195,
#  'told': 196,
#  'Go': 197,
#  'drink': 198,
#  'added': 199,
#  'To': 200,
#  'nachos': 201,
#  'dried': 202,
#  '*heart*': 203,
#  'bruschetta': 204,
#  'Sushi': 205,
#  'starving': 206,
#  'trap': 207,
#  'PERFECT': 208,
#  'extensive': 209,
#  'absolutely': 210,
#  'since': 211,
#  'impressive': 212,
#  'begin': 213,
#  'bits': 214,
#  'melt': 215,
#  'passed': 216,
#  'guess': 217,
#  'needed': 218,
#  'restaurants': 219,
#  'servers': 220,
#  'Otto': 221,
#  'hummus': 222,
#  'hostess': 223,
#  'amount': 224,
#  'six': 225,
#  'Furthermore': 226,
#  'MANY': 227,
#  'why': 228,
#  'bland': 229,
#  'iced': 230,
#  'bye': 231,
#  'hopes': 232,
#  'prime': 233,
#  'fish': 234,
#  'course': 235,
#  'crisp': 236,
#  'area/': 237,
#  'Avoid': 238,
#  'sliced': 239,
#  'outside': 240,
#  'occasional': 241,
#  'wagyu': 242,
#  'orders': 243,
#  'Went': 244,
#  'noodles': 245,
#  '.': 246,
#  'privileged': 247,
#  'Standard': 248,
#  'started': 249,
#  'rotating': 250,
#  'Insults': 251,
#  'as': 252,
#  'crusty': 253,
#  'belly': 254,
#  'sporting': 255,
#  'rice': 256,
#  '``': 257,
#  'high': 258,
#  'worst': 259,
#  'hours': 260,
#  'care': 261,
#  'par': 262,
#  'damn': 263,
#  'totally': 264,
#  'min': 265,
#  'slices': 266,
#  'beef': 267,
#  'wrapped': 268,
#  'Unfortunately': 269,
#  'ALL': 270,
#  'boys': 271,
#  'article': 272,
#  'airport': 273,
#  'myself': 274,
#  'Tasted': 275,
#  'strip': 276,
#  'completely': 277,
#  'known': 278,
#  'rinse': 279,
#  'strange': 280,
#  'Disappointed': 281,
#  'FLAVOR': 282,
#  'deserves': 283,
#  'insanely': 284,
#  'consider': 285,
#  'stretch': 286,
#  'Waiter': 287,
#  'Strip': 288,
#  'VERY': 289,
#  'loved': 290,
#  'grow': 291,
#  'weekend': 292,
#  'ground': 293,
#  'quickly': 294,
#  'tepid': 295,
#  'asked': 296,
#  'later': 297,
#  'arriving': 298,
#  'classics': 299,
#  'thats': 300,
#  'preparing': 301,
#  'disappoint': 302,
#  'name': 303,
#  'opinion': 304,
#  'Loved': 305,
#  'REAL': 306,
#  'cheese': 307,
#  'running': 308,
#  'middle': 309,
#  'mojitos': 310,
#  'favor': 311,
#  'dessert': 312,
#  'under': 313,
#  'Which': 314,
#  'REALLY': 315,
#  'prices': 316,
#  'year': 317,
#  'forth': 318,
#  'excellent': 319,
#  'my': 320,
#  'dishes': 321,
#  'absolutley': 322,
#  'fuzzy': 323,
#  'giving': 324,
#  'vinegrette': 325,
#  'grocery': 326,
#  'frustrated': 327,
#  'silently': 328,
#  'smoothies': 329,
#  'understand': 330,
#  'us': 331,
#  'thought': 332,
#  'waited': 333,
#  '1979': 334,
#  '-': 335,
#  'dealing': 336,
#  'topic': 337,
#  '!': 338,
#  'soon': 339,
#  'been-stepped-in-and-tracked-everywhere': 340,
#  'Ians': 341,
#  'hottest': 342,
#  'Check': 343,
#  'Han': 344,
#  'Bay': 345,
#  'touch': 346,
#  'deuchebaggery': 347,
#  'thanks': 348,
#  'STALE': 349,
#  'folks': 350,
#  'Have': 351,
#  'Penne': 352,
#  'located': 353,
#  'businesses': 354,
#  'Heart': 355,
#  "'re": 356,
#  'uninspired': 357,
#  'duo': 358,
#  'unique': 359,
#  'else': 360,
#  'Extremely': 361,
#  'simply': 362,
#  'scallop': 363,
#  'tasty': 364,
#  'gross': 365,
#  'decorated': 366,
#  'be': 367,
#  'serivce': 368,
#  'Soggy': 369,
#  'flirting': 370,
#  'Grill': 371,
#  'flavorless': 372,
#  'creamy': 373,
#  'Buffet': 374,
#  'proclaimed': 375,
#  'cause': 376,
#  'cold': 377,
#  'biggest': 378,
#  'fluffy': 379,
#  'Will': 380,
#  'visited': 381,
#  'cooked': 382,
#  '.way': 383,
#  'like': 384,
#  'toro': 385,
#  'Very': 386,
#  'considering': 387,
#  'out': 388,
#  'heard': 389,
#  'to': 390,
#  'gooodd': 391,
#  'terrible': 392,
#  'concern': 393,
#  'almost': 394,
#  'ribeye': 395,
#  'Every': 396,
#  'Long': 397,
#  'cheap': 398,
#  'Eew': 399,
#  'Luke': 400,
#  'staff': 401,
#  'during': 402,
#  'restaurant': 403,
#  'Camelback': 404,
#  'half': 405,
#  'violinists': 406,
#  'Salad': 407,
#  'website': 408,
#  'Cartel': 409,
#  'Waitress': 410,
#  'every': 411,
#  'across': 412,
#  'somethat': 413,
#  'would': 414,
#  'never': 415,
#  'cheeseburger': 416,
#  'sandwiches': 417,
#  'held': 418,
#  'final': 419,
#  'THIS': 420,
#  'ensued': 421,
#  'slaw': 422,
#  'eating': 423,
#  'taco': 424,
#  'clean': 425,
#  'few': 426,
#  'Before': 427,
#  'thirty': 428,
#  'me..Bunch': 429,
#  'over-priced': 430,
#  'certainly': 431,
#  'the': 432,
#  'felt': 433,
#  'polite': 434,
#  'Yama': 435,
#  'point': 436,
#  'monster': 437,
#  'salmon': 438,
#  'chickens': 439,
#  'largely': 440,
#  'sucker': 441,
#  '17': 442,
#  'Favorite': 443,
#  'banana': 444,
#  'Awful': 445,
#  'mayo': 446,
#  'maintaining': 447,
#  'Sat': 448,
#  'about': 449,
#  'refrained': 450,
#  'drawing': 451,
#  'HAVE': 452,
#  'Area': 453,
#  'dining': 454,
#  'delivery': 455,
#  'talk': 456,
#  'auju': 457,
#  'nice': 458,
#  'finger': 459,
#  'Only': 460,
#  'still': 461,
#  'puréed': 462,
#  'tell': 463,
#  'AN': 464,
#  'treat': 465,
#  'how': 466,
#  'company': 467,
#  '10+': 468,
#  'Bellagio': 469,
#  'dusted': 470,
#  'rude': 471,
#  'into': 472,
#  '2': 473,
#  'UNREAL': 474,
#  'Boy': 475,
#  'Classy/warm': 476,
#  'buying': 477,
#  '20': 478,
#  'peanut': 479,
#  'piece': 480,
#  'Ramsey': 481,
#  'event': 482,
#  'item': 483,
#  'Chinese': 484,
#  'poop': 485,
#  'surprise': 486,
#  'imagined': 487,
#  'family': 488,
#  'chow': 489,
#  'eyes': 490,
#  'rate': 491,
#  'disagree': 492,
#  'given': 493,
#  'waiter': 494,
#  'no': 495,
#  'shawarrrrrrma': 496,
#  'rowdy': 497,
#  'rushed': 498,
#  'profiterole': 499,
#  'hospitality': 500,
#  'though': 501,
#  'Noca': 502,
#  'expert/connisseur': 503,
#  'assure': 504,
#  'flop': 505,
#  'humiliated': 506,
#  'ignore': 507,
#  'industry': 508,
#  'ranch': 509,
#  'Mushroom': 510,
#  'OMG': 511,
#  'blue': 512,
#  'beateous': 513,
#  'paper': 514,
#  'multiple': 515,
#  'services': 516,
#  'area': 517,
#  'She': 518,
#  'count': 519,
#  'honest': 520,
#  'kept': 521,
#  'disappointment': 522,
#  'watch': 523,
#  'worth': 524,
#  'delight': 525,
#  'suggest': 526,
#  'thinly': 527,
#  'Pineapple': 528,
#  'ago': 529,
#  'crowd': 530,
#  'Not': 531,
#  'crawfish': 532,
#  'correct': 533,
#  'styrofoam': 534,
#  'must-stop': 535,
#  'parents': 536,
#  'Cant': 537,
#  'crab': 538,
#  'quit': 539,
#  'waitress': 540,
#  'including': 541,
#  'fairly': 542,
#  'smaller': 543,
#  'waitresses': 544,
#  'grandmother': 545,
#  'Wo': 546,
#  'tartare': 547,
#  'love': 548,
#  'stayed': 549,
#  'white': 550,
#  '40': 551,
#  'tea': 552,
#  'Third': 553,
#  'PEOPLE': 554,
#  'moz': 555,
#  'top': 556,
#  'job': 557,
#  'dinner': 558,
#  '.the': 559,
#  'realized': 560,
#  'baby': 561,
#  'Maria': 562,
#  'oysters': 563,
#  'honor': 564,
#  'Sunday': 565,
#  'changing': 566,
#  'relaxed': 567,
#  'bone': 568,
#  'soggy': 569,
#  'biscuits': 570,
#  'wire': 571,
#  'decent': 572,
#  'gem': 573,
#  'spicier': 574,
#  'entire': 575,
#  'checked': 576,
#  'generic': 577,
#  'Delight': 578,
#  'mussels': 579,
#  'packed': 580,
#  'home': 581,
#  'menus': 582,
#  'part': 583,
#  'dinners': 584,
#  'non-customer': 585,
#  'butter': 586,
#  'ones': 587,
#  'LEGIT': 588,
#  'easily': 589,
#  'lived': 590,
#  'absolute': 591,
#  'Chicken': 592,
#  'am': 593,
#  'refill': 594,
#  'stupid': 595,
#  'Firehouse': 596,
#  'But': 597,
#  'Nothing': 598,
#  'Spend': 599,
#  'complaints': 600,
#  'because': 601,
#  'perfectly': 602,
#  'behind': 603,
#  'Coming': 604,
#  'said': 605,
#  'lovers': 606,
#  'papers': 607,
#  'pace': 608,
#  'publicly': 609,
#  'hearts': 610,
#  'wines': 611,
#  'leftover': 612,
#  'godfathers': 613,
#  'delightful': 614,
#  'much': 615,
#  'Good': 616,
#  'is': 617,
#  '..there': 618,
#  'venue': 619,
#  'calligraphy': 620,
#  'highlights': 621,
#  'fella': 622,
#  'dressing': 623,
#  'couple': 624,
#  'Mandalay': 625,
#  'appetizers': 626,
#  'law': 627,
#  'buffets': 628,
#  'unwrapped': 629,
#  'circumstances': 630,
#  'spends': 631,
#  'metro': 632,
#  'kiddos': 633,
#  'gave': 634,
#  'reservation': 635,
#  'portion': 636,
#  'always': 637,
#  'There': 638,
#  'drinks': 639,
#  'disaster': 640,
#  'tummy': 641,
#  'cut': 642,
#  'Based': 643,
#  'meatballs': 644,
#  'coziness': 645,
#  'nigiri': 646,
#  '2007': 647,
#  'fruit': 648,
#  'cocktails': 649,
#  'Sorry': 650,
#  'describing': 651,
#  'fast': 652,
#  'offers': 653,
#  'Would': 654,
#  'warmer': 655,
#  'hi': 656,
#  'highlight': 657,
#  'couples': 658,
#  '1': 659,
#  'blame': 660,
#  'joint': 661,
#  'delicioso': 662,
#  '10': 663,
#  'vibe': 664,
#  'focused': 665,
#  'class': 666,
#  'customers': 667,
#  'Left': 668,
#  'Four': 669,
#  'elsewhere': 670,
#  'MGM': 671,
#  'will': 672,
#  'pleasant': 673,
#  'rather': 674,
#  'allergy': 675,
#  'cool': 676,
#  'seems': 677,
#  'reasonably': 678,
#  'mary': 679,
#  'appealing': 680,
#  'may': 681,
#  'Great': 682,
#  'prompt': 683,
#  'others': 684,
#  'tender': 685,
#  'Chipotle': 686,
#  'boyfriend': 687,
#  'unprofessional': 688,
#  'yummy': 689,
#  'dispenser': 690,
#  'satisfying': 691,
#  'If': 692,
#  'constructed': 693,
#  'almonds': 694,
#  'vodka': 695,
#  'rancheros': 696,
#  'Hopefully': 697,
#  'imagine': 698,
#  'piano': 699,
#  'covered': 700,
#  'parties': 701,
#  'Bean': 702,
#  'OF': 703,
#  'carbs': 704,
#  'disapppointment': 705,
#  'wall': 706,
#  'angry': 707,
#  'jalapeno': 708,
#  'reason': 709,
#  'Phenomenal': 710,
#  'medium': 711,
#  'tough': 712,
#  'from': 713,
#  'meh': 714,
#  'By': 715,
#  'included': 716,
#  'salsa': 717,
#  'Host': 718,
#  'Of': 719,
#  'mortified': 720,
#  '70+': 721,
#  'Baseball': 722,
#  'witnessed': 723,
#  'brings': 724,
#  'apology': 725,
#  'loves': 726,
#  'English': 727,
#  'being': 728,
#  'replenished': 729,
#  'combo': 730,
#  'High-quality': 731,
#  'oil': 732,
#  'charcoal': 733,
#  'yum': 734,
#  'fill': 735,
#  'Eclectic': 736,
#  'date': 737,
#  'possible': 738,
#  'We': 739,
#  'reviews': 740,
#  'revisiting': 741,
#  'good': 742,
#  'right': 743,
#  'money': 744,
#  'fondue': 745,
#  'up': 746,
#  'Joey': 747,
#  'new': 748,
#  'BEST': 749,
#  'tolerance': 750,
#  'amazing': 751,
#  'From': 752,
#  '45': 753,
#  'movies': 754,
#  'dont': 755,
#  'server': 756,
#  'meatloaf': 757,
#  'unless': 758,
#  'turkey': 759,
#  'fried': 760,
#  'guests': 761,
#  'shoots': 762,
#  'helped': 763,
#  'excuse': 764,
#  'might': 765,
#  'shops': 766,
#  'lots': 767,
#  'joke': 768,
#  'peach': 769,
#  'An': 770,
#  'saffron': 771,
#  'Awesome': 772,
#  'around': 773,
#  'once': 774,
#  'Lordy': 775,
#  'outta': 776,
#  'fo': 777,
#  'sub': 778,
#  'patio': 779,
#  'staying': 780,
#  'overall': 781,
#  'busy': 782,
#  'Edinburgh': 783,
#  'clue': 784,
#  'Honeslty': 785,
#  'Lobster': 786,
#  'besides': 787,
#  'sashimi': 788,
#  'Rice': 789,
#  'opened': 790,
#  'hamburger': 791,
#  'even': 792,
#  'Bachi': 793,
#  'rave': 794,
#  'past': 795,
#  'hurry': 796,
#  'those': 797,
#  'cashew': 798,
#  'trippy': 799,
#  'definitely': 800,
#  'moods': 801,
#  'look': 802,
#  'yucky': 803,
#  'send': 804,
#  'steakhouse': 805,
#  'effort': 806,
#  'immediately': 807,
#  'HOUR': 808,
#  'fabulous': 809,
#  'carpaccio': 810,
#  'Wife': 811,
#  'sals': 812,
#  'obviously': 813,
#  'Took': 814,
#  'outstanding': 815,
#  'duck': 816,
#  'DELICIOUS': 817,
#  'Dylan': 818,
#  'each': 819,
#  'while': 820,
#  'Worse': 821,
#  'concept': 822,
#  'companions': 823,
#  'meals': 824,
#  'BBQ': 825,
#  'choose': 826,
#  'neighborhood': 827,
#  'reasonable': 828,
#  'pleasure': 829,
#  'Strike': 830,
#  'Greek': 831,
#  'forever': 832,
#  'blow': 833,
#  'flavored': 834,
#  'asking': 835,
#  'freaking': 836,
#  'Mango': 837,
#  'I': 838,
#  'only': 839,
#  'downside': 840,
#  'military': 841,
#  'taste': 842,
#  'enthusiastic': 843,
#  'FANTASTIC': 844,
#  'free': 845,
#  'hella': 846,
#  'Hell': 847,
#  'sever': 848,
#  'neither': 849,
#  'check': 850,
#  'Customer': 851,
#  'complain': 852,
#  'modern': 853,
#  'They': 854,
#  'lukewarm': 855,
#  'pears': 856,
#  'thing': 857,
#  'breakfast': 858,
#  'containers': 859,
#  'Ha': 860,
#  'Any': 861,
#  'boring': 862,
#  'mess': 863,
#  'southwest': 864,
#  'Today': 865,
#  'Sprouts': 866,
#  'table': 867,
#  'highly': 868,
#  'reduction': 869,
#  'owners': 870,
#  'expectations': 871,
#  'dreamed': 872,
#  'driest': 873,
#  'decide': 874,
#  'He': 875,
#  'EXPERIENCE': 876,
#  'lost': 877,
#  'continue': 878,
#  'worker': 879,
#  'luck': 880,
#  'returning': 881,
#  'expanded': 882,
#  'watered': 883,
#  'seating': 884,
#  'ala': 885,
#  'Point': 886,
#  'providing': 887,
#  'awful': 888,
#  'Blah': 889,
#  'yukon': 890,
#  'sugar': 891,
#  'bought': 892,
#  'fell': 893,
#  'Tucson': 894,
#  'last': 895,
#  'Hands': 896,
#  'toasted': 897,
#  'Casino': 898,
#  'atrocious': 899,
#  'delights': 900,
#  'showed': 901,
#  'bit': 902,
#  'nay': 903,
#  'Philadelphia': 904,
#  'charming': 905,
#  'downtown': 906,
#  'price': 907,
#  'manager': 908,
#  'pasta': 909,
#  'box': 910,
#  'looked': 911,
#  'big': 912,
#  'due': 913,
#  'Same': 914,
#  'old': 915,
#  'spicy': 916,
#  'Love': 917,
#  'menu': 918,
#  'your': 919,
#  'looks': 920,
#  'choux': 921,
#  'hated': 922,
#  'colder': 923,
#  'over-hip': 924,
#  'appetizer': 925,
#  'Pita': 926,
#  'his': 927,
#  'ask': 928,
#  'happened': 929,
#  'truly': 930,
#  'glass': 931,
#  'wasting': 932,
#  'cover': 933,
#  'inflate': 934,
#  'Mom': 935,
#  'smells': 936,
#  'pastry': 937,
#  'ripped': 938,
#  'hungry': 939,
#  'sugary': 940,
#  'sushi': 941,
#  'doughy': 942,
#  'Could': 943,
#  'wanted': 944,
#  'experience': 945,
#  'sucked': 946,
#  'favorite': 947,
#  'fantastic': 948,
#  'promptly': 949,
#  'mile': 950,
#  'gyros': 951,
#  'struggle': 952,
#  'did': 953,
#  'longer': 954,
#  'opposed': 955,
#  'seriously': 956,
#  'human': 957,
#  'approval': 958,
#  'lacking': 959,
#  'Fridays': 960,
#  'atmosphere': 961,
#  'become': 962,
#  'words': 963,
#  'plain': 964,
#  'TOTAL': 965,
#  'Phoenix': 966,
#  'chips': 967,
#  'yellowtail': 968,
#  'grease': 969,
#  'greatest': 970,
#  'hilarious': 971,
#  'stuff': 972,
#  'limited': 973,
#  'find': 974,
#  'Stars': 975,
#  'wow': 976,
#  'Wienerschnitzel': 977,
#  '7': 978,
#  'managed': 979,
#  'supposed': 980,
#  'Seriously': 981,
#  'unexperienced': 982,
#  'reviewer': 983,
#  'attack': 984,
#  'T.': 985,
#  'if': 986,
#  'day': 987,
#  'they': 988,
#  'overpriced': 989,
#  'qualified': 990,
#  'apple': 991,
#  'hands-down': 992,
#  'hereas': 993,
#  'occasions': 994,
#  'disappointed': 995,
#  'building': 996,
#  'disgusted': 997,
#  'reminds': 998,
#  'enough..': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'Up',
#  1: 'salt',
#  2: 'flavourful',
#  3: 'Please',
#  4: 'Bar',
#  5: 'other',
#  6: 'bamboo',
#  7: 'room',
#  8: 'deep',
#  9: 'batch',
#  10: 'number',
#  11: 'appalling',
#  12: 'soup',
#  13: 'postinos',
#  14: 'As',
#  15: 'anyone',
#  16: 'dates',
#  17: 'needs',
#  18: 'fellow',
#  19: 'mean',
#  20: 'comfortable',
#  21: 'handed',
#  22: 'cheek',
#  23: 'fails',
#  24: 'non-fancy',
#  25: 'must',
#  26: 'afternoon',
#  27: 'several',
#  28: 'together',
#  29: 'our',
#  30: 'Service',
#  31: 'sick',
#  32: 'perfection',
#  33: 'call',
#  34: 'Thus',
#  35: 'Once',
#  36: 'juries',
#  37: 'Del',
#  38: 'head',
#  39: 'try',
#  40: 'transcendant',
#  41: 'further',
#  42: '40min',
#  43: 'sewer',
#  44: 'descriptions',
#  45: '35',
#  46: 'claimed',
#  47: 'Veggitarian',
#  48: 'quite',
#  49: 'Burrittos',
#  50: 'listed',
#  51: 'reviewing..',
#  52: 'calamari',
#  53: 'quantity',
#  54: 'greedy',
#  55: 'very',
#  56: 'contained',
#  57: 'Damn',
#  58: 'Yeah',
#  59: 'gratuity',
#  60: 'rated',
#  61: 'horrible',
#  62: 'figured',
#  63: '3',
#  64: 'North',
#  65: 'playing',
#  66: 'brick',
#  67: 'IT',
#  68: 'bring',
#  69: 'Con',
#  70: 'mention',
#  71: 'black',
#  72: 'Bacon',
#  73: 'disbelief',
#  74: 'Café',
#  75: 'seated',
#  76: 'WEAK',
#  77: 'disrespected',
#  78: 'ice',
#  79: 'done',
#  80: 'temp.I',
#  81: 'ethic',
#  82: 'indoor',
#  83: '%',
#  84: 'Tried',
#  85: 'nude',
#  86: 'eyed',
#  87: 'mood',
#  88: 'STEP',
#  89: 'experienced',
#  90: 'having',
#  91: 'RI',
#  92: 'also',
#  93: 'strawberry',
#  94: 'OVERPRICED',
#  95: 'tap',
#  96: 'multi-grain',
#  97: 'door',
#  98: 'Be',
#  99: 'street',
#  100: 'disgusting',
#  101: 'Italian',
#  102: 'potato',
#  103: 'One',
#  104: 'eggplant',
#  105: 'wave',
#  106: 'summarize',
#  107: 'definately',
#  108: 'callings',
#  109: 'NONE',
#  110: 'For',
#  111: 'anymore',
#  112: 'Steiners',
#  113: 'suggestions',
#  114: 'Salads',
#  115: 'meats',
#  116: 'help',
#  117: 'one',
#  118: 'seasonal',
#  119: 'Some',
#  120: 'array',
#  121: 'disgust',
#  122: 'ladies',
#  123: 'etc',
#  124: 'brother',
#  125: 'strings',
#  126: '.very',
#  127: 'HAPPENED',
#  128: 'tasteless',
#  129: 'bagels',
#  130: 'wash',
#  131: 'great',
#  132: 'should',
#  133: 'awesome',
#  134: 'of',
#  135: 'milkshake',
#  136: 'These',
#  137: "ya'all",
#  138: 'closed',
#  139: 'low-key',
#  140: 'recommended',
#  141: 'Indian',
#  142: 'chipolte',
#  143: 'exquisite',
#  144: 'Everyone',
#  145: 'outshining',
#  146: 'Gyros',
#  147: 'Interesting',
#  148: 'Shop',
#  149: 'suck',
#  150: 'least',
#  151: 'AGAIN',
#  152: 'bakery',
#  153: 'above',
#  154: 'mains',
#  155: 'got',
#  156: 'Thoroughly',
#  157: "'d",
#  158: 'cafe',
#  159: 'Sour',
#  160: 'drive',
#  161: 'double',
#  162: 'Christmas',
#  163: 'owner',
#  164: 'workers',
#  165: 'friend',
#  166: 'impressed',
#  167: 'perfect',
#  168: 'deliver',
#  169: 'mozzarella',
#  170: 'operation',
#  171: 'Japanese',
#  172: 'ridiculous',
#  173: 'unhealthy',
#  174: 'meal',
#  175: 'service',
#  176: 'Nan',
#  177: 'melted',
#  178: 'bartender',
#  179: 'Voodoo',
#  180: 'GO',
#  181: 'either',
#  182: 'correction',
#  183: 'missing',
#  184: 'then',
#  185: 'original',
#  186: 'stir',
#  187: 'tater',
#  188: 'dog',
#  189: 'homemade',
#  190: 'lawyers',
#  191: 'tuna',
#  192: 'Lastly',
#  193: 'Oh',
#  194: 'bother',
#  195: 'Disappointing',
#  196: 'told',
#  197: 'Go',
#  198: 'drink',
#  199: 'added',
#  200: 'To',
#  201: 'nachos',
#  202: 'dried',
#  203: '*heart*',
#  204: 'bruschetta',
#  205: 'Sushi',
#  206: 'starving',
#  207: 'trap',
#  208: 'PERFECT',
#  209: 'extensive',
#  210: 'absolutely',
#  211: 'since',
#  212: 'impressive',
#  213: 'begin',
#  214: 'bits',
#  215: 'melt',
#  216: 'passed',
#  217: 'guess',
#  218: 'needed',
#  219: 'restaurants',
#  220: 'servers',
#  221: 'Otto',
#  222: 'hummus',
#  223: 'hostess',
#  224: 'amount',
#  225: 'six',
#  226: 'Furthermore',
#  227: 'MANY',
#  228: 'why',
#  229: 'bland',
#  230: 'iced',
#  231: 'bye',
#  232: 'hopes',
#  233: 'prime',
#  234: 'fish',
#  235: 'course',
#  236: 'crisp',
#  237: 'area/',
#  238: 'Avoid',
#  239: 'sliced',
#  240: 'outside',
#  241: 'occasional',
#  242: 'wagyu',
#  243: 'orders',
#  244: 'Went',
#  245: 'noodles',
#  246: '.',
#  247: 'privileged',
#  248: 'Standard',
#  249: 'started',
#  250: 'rotating',
#  251: 'Insults',
#  252: 'as',
#  253: 'crusty',
#  254: 'belly',
#  255: 'sporting',
#  256: 'rice',
#  257: '``',
#  258: 'high',
#  259: 'worst',
#  260: 'hours',
#  261: 'care',
#  262: 'par',
#  263: 'damn',
#  264: 'totally',
#  265: 'min',
#  266: 'slices',
#  267: 'beef',
#  268: 'wrapped',
#  269: 'Unfortunately',
#  270: 'ALL',
#  271: 'boys',
#  272: 'article',
#  273: 'airport',
#  274: 'myself',
#  275: 'Tasted',
#  276: 'strip',
#  277: 'completely',
#  278: 'known',
#  279: 'rinse',
#  280: 'strange',
#  281: 'Disappointed',
#  282: 'FLAVOR',
#  283: 'deserves',
#  284: 'insanely',
#  285: 'consider',
#  286: 'stretch',
#  287: 'Waiter',
#  288: 'Strip',
#  289: 'VERY',
#  290: 'loved',
#  291: 'grow',
#  292: 'weekend',
#  293: 'ground',
#  294: 'quickly',
#  295: 'tepid',
#  296: 'asked',
#  297: 'later',
#  298: 'arriving',
#  299: 'classics',
#  300: 'thats',
#  301: 'preparing',
#  302: 'disappoint',
#  303: 'name',
#  304: 'opinion',
#  305: 'Loved',
#  306: 'REAL',
#  307: 'cheese',
#  308: 'running',
#  309: 'middle',
#  310: 'mojitos',
#  311: 'favor',
#  312: 'dessert',
#  313: 'under',
#  314: 'Which',
#  315: 'REALLY',
#  316: 'prices',
#  317: 'year',
#  318: 'forth',
#  319: 'excellent',
#  320: 'my',
#  321: 'dishes',
#  322: 'absolutley',
#  323: 'fuzzy',
#  324: 'giving',
#  325: 'vinegrette',
#  326: 'grocery',
#  327: 'frustrated',
#  328: 'silently',
#  329: 'smoothies',
#  330: 'understand',
#  331: 'us',
#  332: 'thought',
#  333: 'waited',
#  334: '1979',
#  335: '-',
#  336: 'dealing',
#  337: 'topic',
#  338: '!',
#  339: 'soon',
#  340: 'been-stepped-in-and-tracked-everywhere',
#  341: 'Ians',
#  342: 'hottest',
#  343: 'Check',
#  344: 'Han',
#  345: 'Bay',
#  346: 'touch',
#  347: 'deuchebaggery',
#  348: 'thanks',
#  349: 'STALE',
#  350: 'folks',
#  351: 'Have',
#  352: 'Penne',
#  353: 'located',
#  354: 'businesses',
#  355: 'Heart',
#  356: "'re",
#  357: 'uninspired',
#  358: 'duo',
#  359: 'unique',
#  360: 'else',
#  361: 'Extremely',
#  362: 'simply',
#  363: 'scallop',
#  364: 'tasty',
#  365: 'gross',
#  366: 'decorated',
#  367: 'be',
#  368: 'serivce',
#  369: 'Soggy',
#  370: 'flirting',
#  371: 'Grill',
#  372: 'flavorless',
#  373: 'creamy',
#  374: 'Buffet',
#  375: 'proclaimed',
#  376: 'cause',
#  377: 'cold',
#  378: 'biggest',
#  379: 'fluffy',
#  380: 'Will',
#  381: 'visited',
#  382: 'cooked',
#  383: '.way',
#  384: 'like',
#  385: 'toro',
#  386: 'Very',
#  387: 'considering',
#  388: 'out',
#  389: 'heard',
#  390: 'to',
#  391: 'gooodd',
#  392: 'terrible',
#  393: 'concern',
#  394: 'almost',
#  395: 'ribeye',
#  396: 'Every',
#  397: 'Long',
#  398: 'cheap',
#  399: 'Eew',
#  400: 'Luke',
#  401: 'staff',
#  402: 'during',
#  403: 'restaurant',
#  404: 'Camelback',
#  405: 'half',
#  406: 'violinists',
#  407: 'Salad',
#  408: 'website',
#  409: 'Cartel',
#  410: 'Waitress',
#  411: 'every',
#  412: 'across',
#  413: 'somethat',
#  414: 'would',
#  415: 'never',
#  416: 'cheeseburger',
#  417: 'sandwiches',
#  418: 'held',
#  419: 'final',
#  420: 'THIS',
#  421: 'ensued',
#  422: 'slaw',
#  423: 'eating',
#  424: 'taco',
#  425: 'clean',
#  426: 'few',
#  427: 'Before',
#  428: 'thirty',
#  429: 'me..Bunch',
#  430: 'over-priced',
#  431: 'certainly',
#  432: 'the',
#  433: 'felt',
#  434: 'polite',
#  435: 'Yama',
#  436: 'point',
#  437: 'monster',
#  438: 'salmon',
#  439: 'chickens',
#  440: 'largely',
#  441: 'sucker',
#  442: '17',
#  443: 'Favorite',
#  444: 'banana',
#  445: 'Awful',
#  446: 'mayo',
#  447: 'maintaining',
#  448: 'Sat',
#  449: 'about',
#  450: 'refrained',
#  451: 'drawing',
#  452: 'HAVE',
#  453: 'Area',
#  454: 'dining',
#  455: 'delivery',
#  456: 'talk',
#  457: 'auju',
#  458: 'nice',
#  459: 'finger',
#  460: 'Only',
#  461: 'still',
#  462: 'puréed',
#  463: 'tell',
#  464: 'AN',
#  465: 'treat',
#  466: 'how',
#  467: 'company',
#  468: '10+',
#  469: 'Bellagio',
#  470: 'dusted',
#  471: 'rude',
#  472: 'into',
#  473: '2',
#  474: 'UNREAL',
#  475: 'Boy',
#  476: 'Classy/warm',
#  477: 'buying',
#  478: '20',
#  479: 'peanut',
#  480: 'piece',
#  481: 'Ramsey',
#  482: 'event',
#  483: 'item',
#  484: 'Chinese',
#  485: 'poop',
#  486: 'surprise',
#  487: 'imagined',
#  488: 'family',
#  489: 'chow',
#  490: 'eyes',
#  491: 'rate',
#  492: 'disagree',
#  493: 'given',
#  494: 'waiter',
#  495: 'no',
#  496: 'shawarrrrrrma',
#  497: 'rowdy',
#  498: 'rushed',
#  499: 'profiterole',
#  500: 'hospitality',
#  501: 'though',
#  502: 'Noca',
#  503: 'expert/connisseur',
#  504: 'assure',
#  505: 'flop',
#  506: 'humiliated',
#  507: 'ignore',
#  508: 'industry',
#  509: 'ranch',
#  510: 'Mushroom',
#  511: 'OMG',
#  512: 'blue',
#  513: 'beateous',
#  514: 'paper',
#  515: 'multiple',
#  516: 'services',
#  517: 'area',
#  518: 'She',
#  519: 'count',
#  520: 'honest',
#  521: 'kept',
#  522: 'disappointment',
#  523: 'watch',
#  524: 'worth',
#  525: 'delight',
#  526: 'suggest',
#  527: 'thinly',
#  528: 'Pineapple',
#  529: 'ago',
#  530: 'crowd',
#  531: 'Not',
#  532: 'crawfish',
#  533: 'correct',
#  534: 'styrofoam',
#  535: 'must-stop',
#  536: 'parents',
#  537: 'Cant',
#  538: 'crab',
#  539: 'quit',
#  540: 'waitress',
#  541: 'including',
#  542: 'fairly',
#  543: 'smaller',
#  544: 'waitresses',
#  545: 'grandmother',
#  546: 'Wo',
#  547: 'tartare',
#  548: 'love',
#  549: 'stayed',
#  550: 'white',
#  551: '40',
#  552: 'tea',
#  553: 'Third',
#  554: 'PEOPLE',
#  555: 'moz',
#  556: 'top',
#  557: 'job',
#  558: 'dinner',
#  559: '.the',
#  560: 'realized',
#  561: 'baby',
#  562: 'Maria',
#  563: 'oysters',
#  564: 'honor',
#  565: 'Sunday',
#  566: 'changing',
#  567: 'relaxed',
#  568: 'bone',
#  569: 'soggy',
#  570: 'biscuits',
#  571: 'wire',
#  572: 'decent',
#  573: 'gem',
#  574: 'spicier',
#  575: 'entire',
#  576: 'checked',
#  577: 'generic',
#  578: 'Delight',
#  579: 'mussels',
#  580: 'packed',
#  581: 'home',
#  582: 'menus',
#  583: 'part',
#  584: 'dinners',
#  585: 'non-customer',
#  586: 'butter',
#  587: 'ones',
#  588: 'LEGIT',
#  589: 'easily',
#  590: 'lived',
#  591: 'absolute',
#  592: 'Chicken',
#  593: 'am',
#  594: 'refill',
#  595: 'stupid',
#  596: 'Firehouse',
#  597: 'But',
#  598: 'Nothing',
#  599: 'Spend',
#  600: 'complaints',
#  601: 'because',
#  602: 'perfectly',
#  603: 'behind',
#  604: 'Coming',
#  605: 'said',
#  606: 'lovers',
#  607: 'papers',
#  608: 'pace',
#  609: 'publicly',
#  610: 'hearts',
#  611: 'wines',
#  612: 'leftover',
#  613: 'godfathers',
#  614: 'delightful',
#  615: 'much',
#  616: 'Good',
#  617: 'is',
#  618: '..there',
#  619: 'venue',
#  620: 'calligraphy',
#  621: 'highlights',
#  622: 'fella',
#  623: 'dressing',
#  624: 'couple',
#  625: 'Mandalay',
#  626: 'appetizers',
#  627: 'law',
#  628: 'buffets',
#  629: 'unwrapped',
#  630: 'circumstances',
#  631: 'spends',
#  632: 'metro',
#  633: 'kiddos',
#  634: 'gave',
#  635: 'reservation',
#  636: 'portion',
#  637: 'always',
#  638: 'There',
#  639: 'drinks',
#  640: 'disaster',
#  641: 'tummy',
#  642: 'cut',
#  643: 'Based',
#  644: 'meatballs',
#  645: 'coziness',
#  646: 'nigiri',
#  647: '2007',
#  648: 'fruit',
#  649: 'cocktails',
#  650: 'Sorry',
#  651: 'describing',
#  652: 'fast',
#  653: 'offers',
#  654: 'Would',
#  655: 'warmer',
#  656: 'hi',
#  657: 'highlight',
#  658: 'couples',
#  659: '1',
#  660: 'blame',
#  661: 'joint',
#  662: 'delicioso',
#  663: '10',
#  664: 'vibe',
#  665: 'focused',
#  666: 'class',
#  667: 'customers',
#  668: 'Left',
#  669: 'Four',
#  670: 'elsewhere',
#  671: 'MGM',
#  672: 'will',
#  673: 'pleasant',
#  674: 'rather',
#  675: 'allergy',
#  676: 'cool',
#  677: 'seems',
#  678: 'reasonably',
#  679: 'mary',
#  680: 'appealing',
#  681: 'may',
#  682: 'Great',
#  683: 'prompt',
#  684: 'others',
#  685: 'tender',
#  686: 'Chipotle',
#  687: 'boyfriend',
#  688: 'unprofessional',
#  689: 'yummy',
#  690: 'dispenser',
#  691: 'satisfying',
#  692: 'If',
#  693: 'constructed',
#  694: 'almonds',
#  695: 'vodka',
#  696: 'rancheros',
#  697: 'Hopefully',
#  698: 'imagine',
#  699: 'piano',
#  700: 'covered',
#  701: 'parties',
#  702: 'Bean',
#  703: 'OF',
#  704: 'carbs',
#  705: 'disapppointment',
#  706: 'wall',
#  707: 'angry',
#  708: 'jalapeno',
#  709: 'reason',
#  710: 'Phenomenal',
#  711: 'medium',
#  712: 'tough',
#  713: 'from',
#  714: 'meh',
#  715: 'By',
#  716: 'included',
#  717: 'salsa',
#  718: 'Host',
#  719: 'Of',
#  720: 'mortified',
#  721: '70+',
#  722: 'Baseball',
#  723: 'witnessed',
#  724: 'brings',
#  725: 'apology',
#  726: 'loves',
#  727: 'English',
#  728: 'being',
#  729: 'replenished',
#  730: 'combo',
#  731: 'High-quality',
#  732: 'oil',
#  733: 'charcoal',
#  734: 'yum',
#  735: 'fill',
#  736: 'Eclectic',
#  737: 'date',
#  738: 'possible',
#  739: 'We',
#  740: 'reviews',
#  741: 'revisiting',
#  742: 'good',
#  743: 'right',
#  744: 'money',
#  745: 'fondue',
#  746: 'up',
#  747: 'Joey',
#  748: 'new',
#  749: 'BEST',
#  750: 'tolerance',
#  751: 'amazing',
#  752: 'From',
#  753: '45',
#  754: 'movies',
#  755: 'dont',
#  756: 'server',
#  757: 'meatloaf',
#  758: 'unless',
#  759: 'turkey',
#  760: 'fried',
#  761: 'guests',
#  762: 'shoots',
#  763: 'helped',
#  764: 'excuse',
#  765: 'might',
#  766: 'shops',
#  767: 'lots',
#  768: 'joke',
#  769: 'peach',
#  770: 'An',
#  771: 'saffron',
#  772: 'Awesome',
#  773: 'around',
#  774: 'once',
#  775: 'Lordy',
#  776: 'outta',
#  777: 'fo',
#  778: 'sub',
#  779: 'patio',
#  780: 'staying',
#  781: 'overall',
#  782: 'busy',
#  783: 'Edinburgh',
#  784: 'clue',
#  785: 'Honeslty',
#  786: 'Lobster',
#  787: 'besides',
#  788: 'sashimi',
#  789: 'Rice',
#  790: 'opened',
#  791: 'hamburger',
#  792: 'even',
#  793: 'Bachi',
#  794: 'rave',
#  795: 'past',
#  796: 'hurry',
#  797: 'those',
#  798: 'cashew',
#  799: 'trippy',
#  800: 'definitely',
#  801: 'moods',
#  802: 'look',
#  803: 'yucky',
#  804: 'send',
#  805: 'steakhouse',
#  806: 'effort',
#  807: 'immediately',
#  808: 'HOUR',
#  809: 'fabulous',
#  810: 'carpaccio',
#  811: 'Wife',
#  812: 'sals',
#  813: 'obviously',
#  814: 'Took',
#  815: 'outstanding',
#  816: 'duck',
#  817: 'DELICIOUS',
#  818: 'Dylan',
#  819: 'each',
#  820: 'while',
#  821: 'Worse',
#  822: 'concept',
#  823: 'companions',
#  824: 'meals',
#  825: 'BBQ',
#  826: 'choose',
#  827: 'neighborhood',
#  828: 'reasonable',
#  829: 'pleasure',
#  830: 'Strike',
#  831: 'Greek',
#  832: 'forever',
#  833: 'blow',
#  834: 'flavored',
#  835: 'asking',
#  836: 'freaking',
#  837: 'Mango',
#  838: 'I',
#  839: 'only',
#  840: 'downside',
#  841: 'military',
#  842: 'taste',
#  843: 'enthusiastic',
#  844: 'FANTASTIC',
#  845: 'free',
#  846: 'hella',
#  847: 'Hell',
#  848: 'sever',
#  849: 'neither',
#  850: 'check',
#  851: 'Customer',
#  852: 'complain',
#  853: 'modern',
#  854: 'They',
#  855: 'lukewarm',
#  856: 'pears',
#  857: 'thing',
#  858: 'breakfast',
#  859: 'containers',
#  860: 'Ha',
#  861: 'Any',
#  862: 'boring',
#  863: 'mess',
#  864: 'southwest',
#  865: 'Today',
#  866: 'Sprouts',
#  867: 'table',
#  868: 'highly',
#  869: 'reduction',
#  870: 'owners',
#  871: 'expectations',
#  872: 'dreamed',
#  873: 'driest',
#  874: 'decide',
#  875: 'He',
#  876: 'EXPERIENCE',
#  877: 'lost',
#  878: 'continue',
#  879: 'worker',
#  880: 'luck',
#  881: 'returning',
#  882: 'expanded',
#  883: 'watered',
#  884: 'seating',
#  885: 'ala',
#  886: 'Point',
#  887: 'providing',
#  888: 'awful',
#  889: 'Blah',
#  890: 'yukon',
#  891: 'sugar',
#  892: 'bought',
#  893: 'fell',
#  894: 'Tucson',
#  895: 'last',
#  896: 'Hands',
#  897: 'toasted',
#  898: 'Casino',
#  899: 'atrocious',
#  900: 'delights',
#  901: 'showed',
#  902: 'bit',
#  903: 'nay',
#  904: 'Philadelphia',
#  905: 'charming',
#  906: 'downtown',
#  907: 'price',
#  908: 'manager',
#  909: 'pasta',
#  910: 'box',
#  911: 'looked',
#  912: 'big',
#  913: 'due',
#  914: 'Same',
#  915: 'old',
#  916: 'spicy',
#  917: 'Love',
#  918: 'menu',
#  919: 'your',
#  920: 'looks',
#  921: 'choux',
#  922: 'hated',
#  923: 'colder',
#  924: 'over-hip',
#  925: 'appetizer',
#  926: 'Pita',
#  927: 'his',
#  928: 'ask',
#  929: 'happened',
#  930: 'truly',
#  931: 'glass',
#  932: 'wasting',
#  933: 'cover',
#  934: 'inflate',
#  935: 'Mom',
#  936: 'smells',
#  937: 'pastry',
#  938: 'ripped',
#  939: 'hungry',
#  940: 'sugary',
#  941: 'sushi',
#  942: 'doughy',
#  943: 'Could',
#  944: 'wanted',
#  945: 'experience',
#  946: 'sucked',
#  947: 'favorite',
#  948: 'fantastic',
#  949: 'promptly',
#  950: 'mile',
#  951: 'gyros',
#  952: 'struggle',
#  953: 'did',
#  954: 'longer',
#  955: 'opposed',
#  956: 'seriously',
#  957: 'human',
#  958: 'approval',
#  959: 'lacking',
#  960: 'Fridays',
#  961: 'atmosphere',
#  962: 'become',
#  963: 'words',
#  964: 'plain',
#  965: 'TOTAL',
#  966: 'Phoenix',
#  967: 'chips',
#  968: 'yellowtail',
#  969: 'grease',
#  970: 'greatest',
#  971: 'hilarious',
#  972: 'stuff',
#  973: 'limited',
#  974: 'find',
#  975: 'Stars',
#  976: 'wow',
#  977: 'Wienerschnitzel',
#  978: '7',
#  979: 'managed',
#  980: 'supposed',
#  981: 'Seriously',
#  982: 'unexperienced',
#  983: 'reviewer',
#  984: 'attack',
#  985: 'T.',
#  986: 'if',
#  987: 'day',
#  988: 'they',
#  989: 'overpriced',
#  990: 'qualified',
#  991: 'apple',
#  992: 'hands-down',
#  993: 'hereas',
#  994: 'occasions',
#  995: 'disappointed',
#  996: 'building',
#  997: 'disgusted',
#  998: 'reminds',
#  999: 'enough..',
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    vector = np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            vector[word_index[word]]+=1
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])
