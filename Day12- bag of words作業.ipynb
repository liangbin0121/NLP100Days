# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ---

# %%
import os

# Current directory
print(os.getcwd())

# change directory
os.chdir('/content/drive/MyDrive/python_training/NLP100Days/day_12_BOW/')
print(os.getcwd())
! pip install -q sklearn_crfsuite
! pip install -q nltk
! pip install -q scikit-learn
# Out:
# /content/drive/My Drive/python_training/NLP100Days/day_12_BOW
# /content/drive/MyDrive/python_training/NLP100Days/day_12_BOW

# %%
import pandas as pd
import nltk
#nltk.download()
#nltk.download('treebank')
#nltk.download('universal_tagset')
nltk.download('punkt')
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
dataset[0:2]
# Out:
#                      Review  Liked
# 0  Wow... Loved this place.      1
# 1        Crust is not good.      0

# %%
corpus[0:2]
# Out:
# array(['Wow... Loved this place.', 'Crust is not good.'], dtype=object)

# %%
dataset.shape
# Out:
# (1000, 2)

# %% [markdown]
# ### 從文本中取出所有單字

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)

# %%
whole_words[0:9]
# Out:
# ['Wow', '...', 'Loved', 'this', 'place', '.', 'Crust', 'is', 'not']

# %%
len(whole_words)
# Out:
# 12676

# %% [markdown]
# ### 移除重複單字

# %%
temp_stor =[]
w_index =0
#print(range(0,len(temp_stor)))
#print(temp_stor[0])
for sentence in whole_words:
  #print(sentence)
  #temp_stor.append(sentence)
  for i in range(w_index+1):
    #print(temp_stor[i])
    print(i)
    if sentence != temp_stor[i]:
      temp_stor.append(sentence)
      w_index=w_index+1
    else:
      temp_stor.append(sentence)

#whole_words = temp_stor.copy()
print('共有{}個單字'.format(len(whole_words)))
#print('next word: {}, probability: {}'.format(next_word.word, next_word.prob))
# Out:
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-69-0412ccf8107c> in <module>()
#       9     #print(temp_stor[i])
#      10     print(i)
# ---> 11     if sentence != temp_stor[i]:
#      12       temp_stor.append(sentence)
#      13       w_index=w_index+1
#
# IndexError: list index out of range

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    """自行填入"""

# %%
word_index

# %%
index_word

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    '''創建一個vector'''
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            '''自行填入'''
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
